# %%
import pandas as pd
import json
import requests

# %%
kindle_csv = "C:/Users/freak/Downloads/kindle_reviews.csv"
kindle_data = pd.read_csv(kindle_csv)
kindle_data
# Out:
#         Unnamed: 0        asin helpful  overall  \
# 0                0  B000F83SZQ  [0, 0]        5
# 1                1  B000F83SZQ  [2, 2]        4
# 2                2  B000F83SZQ  [2, 2]        4
# 3                3  B000F83SZQ  [1, 1]        5
# 4                4  B000F83SZQ  [0, 1]        4
# ...            ...         ...     ...      ...
# 982614      982614  B00M13FNSS  [2, 2]        5
# 982615      982615  B00M13FNSS  [0, 0]        5
# 982616      982616  B00M13FNSS  [1, 1]        5
# 982617      982617  B00M13FNSS  [0, 0]        5
# 982618      982618  B00M13FNSS  [2, 2]        5
#
#                                                reviewText   reviewTime  \
# 0       I enjoy vintage books and movies so I enjoyed ...   05 5, 2014
# 1       This book is a reissue of an old one; the auth...   01 6, 2014
# 2       This was a fairly interesting read.  It had ol...   04 4, 2014
# 3       I'd never read any of the Amy Brewster mysteri...  02 19, 2014
# ...

# %%
def print_json(x):
    print(json.dumps(x, indent=4, sort_keys=True))

# %%
url = "https://amazon-price1.p.rapidapi.com/search"

querystring = {"keywords":"fantasy","marketplace":"ES"}

headers = {
    'x-rapidapi-key': "3ffa0d66a0msh71abf90e5f08548p169ee4jsn62dac2d9c433",
    'x-rapidapi-host': "amazon-price1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring).json()

print_json(response)
# Out:
# [
#     {
#         "ASIN": "B000I6BMQ2",
#         "detailPageURL": "https://www.amazon.es/dp/B000I6BMQ2",
#         "imageUrl": "https://m.media-amazon.com/images/I/319MKlwCOML._SL160_.jpg",
#         "isPrimeEligible": "1",
#         "listPrice": "",
#         "price": "13,80\u00a0\u20ac (46,00\u00a0\u20ac / 100 ml)",
#         "rating": "4.5",
#         "subtitle": "",
#         "title": "Britney Spears Fantasy Eau de Parfum 30 ml",
#         "totalReviews": "8033"
#     },
#     {
#         "ASIN": "B000M8BE3C",
#         "detailPageURL": "https://www.amazon.es/dp/B000M8BE3C",
#         "imageUrl": "https://m.media-amazon.com/images/I/41wP8Ilg+mL._SL160_.jpg",
#         "isPrimeEligible": "1",
#         "listPrice": "",
#         "price": "19,55\u00a0\u20ac",
#         "rating": "4.5",
#         "subtitle": "",
#         "title": "Britney Spears Midnight Fantasy Eau de Parfum - 100 ml",
#         "totalReviews": "5155"
#     },
#     {
#         "ASIN": "B07WFKNW29",
# ...

# %%
url = "https://amazon-price1.p.rapidapi.com/priceReport"

headers = {
    'x-rapidapi-key': "3ffa0d66a0msh71abf90e5f08548p169ee4jsn62dac2d9c433",
    'x-rapidapi-host': "amazon-price1.p.rapidapi.com"
    }

querystring = {"asin":"B000F83SZQ","marketplace":"ES"}
response = requests.request("GET", url, headers=headers, params=querystring).json()
print_json(response)
# Out:
# {
#     "asin": "B000F83SZQ",
#     "createdAt": "2021-02-08T17:47:07-08:00",
#     "currencySymbol": "\u20ac",
#     "highestPricing": {
#         "priceAmazon": null,
#         "priceNew": null,
#         "priceUsed": null
#     },
#     "lastPrice": {
#         "priceAmazon": null,
#         "priceNew": 287,
#         "priceUsed": null
#     },
#     "lowestPricing": {
#         "priceAmazon": null,
#         "priceNew": null,
#         "priceUsed": null
#     },
#     "notTrackableError": "Lo sentimos, debido a que el Amazon no nos permite seguir \" productos \"Versi\u00f3n Kindle\", no disponemos de ning\u00fan dato de precios para este producto.",
#     "prices": {
#         "priceAmazon": null,
#         "priceNew": 287,
#         "priceUsed": null
#     },
#     "title": "A Matter of Policy [An Amy Brewster Mystery] (English Edition)"
# }

# %%
asin = kindle_data["asin"].unique()
asin
# Out:
# array(['B000F83SZQ', 'B000FA64PA', 'B000FA64PK', ..., 'B00M029T4O',
#        'B00M0RE7CS', 'B00M13FNSS'], dtype=object)

# %%
url = "https://amazon-price1.p.rapidapi.com/search"

querystring = {"keywords":"A Matter of Policy [An Amy Brewster Mystery]","marketplace":"ES"}

headers = {
    'x-rapidapi-key': "3ffa0d66a0msh71abf90e5f08548p169ee4jsn62dac2d9c433",
    'x-rapidapi-host': "amazon-price1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring).json()

print_json(response[0]["price"][0:4])
# Out:
# "2,87"

# %%
url = "https://amazon-price1.p.rapidapi.com/priceReport"

headers = {
    'x-rapidapi-key': "3ffa0d66a0msh71abf90e5f08548p169ee4jsn62dac2d9c433",
    'x-rapidapi-host': "amazon-price1.p.rapidapi.com"
    }

book_title = []


for title in asin:
    try:
        querystring = {"asin":title,"marketplace":"ES"}
        response = requests.request("GET", url, headers=headers, params=querystring).json()
        book_title.append(response["title"])
        print(response["title"])
    except:
        print("Can't find")
# Out:
# A Matter of Policy [An Amy Brewster Mystery] (English Edition)
# Saboteur: Star Wars Legends (Darth Maul) (Short Story) (Star Wars: Darth Maul Book 1) (English Edition)
# Recovery: Star Wars Legends (The New Jedi Order) (Short Story) (Star Wars: The New Jedi Order) (English Edition)
# Ylesia: Star Wars Legends (The New Jedi Order) (Star Wars: The New Jedi Order) (English Edition)
# A Forest Apart: Star Wars Legends (Short Story) (Star Wars - Legends) (English Edition)
# Fool's Bargain: Star Wars Legends (Novella) (Star Wars - Legends) (English Edition)
# The Iron Marshal: A Novel (English Edition)
# Can't find
# Brionne: A Novel (English Edition)
# Can't find
# Can't find
# Can't find
# Can't find
# Can't find
# Can't find
# Can't find
# Can't find
# Grimm's Fairy Stories
# Can't find
# Can't find
# Can't find
# Can't find
# Can't find
# The English Orphans (English Edition)
# Can't find
# Can't find
# Can't find
# Indian Fairy Tales (English Edition)
# ...
