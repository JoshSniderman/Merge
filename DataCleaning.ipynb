# %%
import pandas as pd
import json
import requests
import matplotlib.pyplot as plt

# %%
# Import kindle data

kindle_csv = "C:/Users/freak/Downloads/kindle_reviews.csv"
kindle_data = pd.read_csv(kindle_csv)
kindle_data
# Out:
#         Unnamed: 0        asin helpful  overall  \
# 0                0  B000F83SZQ  [0, 0]        5
# 1                1  B000F83SZQ  [2, 2]        4
# 2                2  B000F83SZQ  [2, 2]        4
# 3                3  B000F83SZQ  [1, 1]        5
# 4                4  B000F83SZQ  [0, 1]        4
# ...            ...         ...     ...      ...
# 982614      982614  B00M13FNSS  [2, 2]        5
# 982615      982615  B00M13FNSS  [0, 0]        5
# 982616      982616  B00M13FNSS  [1, 1]        5
# 982617      982617  B00M13FNSS  [0, 0]        5
# 982618      982618  B00M13FNSS  [2, 2]        5
#
#                                                reviewText   reviewTime  \
# 0       I enjoy vintage books and movies so I enjoyed ...   05 5, 2014
# 1       This book is a reissue of an old one; the auth...   01 6, 2014
# 2       This was a fairly interesting read.  It had ol...   04 4, 2014
# 3       I'd never read any of the Amy Brewster mysteri...  02 19, 2014
# ...

# %%
# Extract null value reviews

review_na = kindle_data.loc[kindle_data["reviewText"].isna(), :]
review_na
# Out:
#         Unnamed: 0        asin   helpful  overall reviewText   reviewTime  \
# 32652        32652  B004AM5EMS    [0, 1]        5        NaN  02 12, 2011
# 143683      143683  B006GWO5WK    [2, 3]        5        NaN  10 23, 2012
# 163443      163443  B006W0PLYW    [2, 2]        5        NaN  09 26, 2012
# 193140      193140  B007JYOS4Y    [1, 1]        3        NaN  03 31, 2013
# 198536      198536  B007O56WOC    [3, 4]        5        NaN   09 9, 2012
# 255972      255972  B008H9Y7I2    [0, 0]        5        NaN   07 8, 2012
# 308493      308493  B009EGS292    [8, 9]        4        NaN  09 22, 2012
# 312057      312057  B009GMXIFM    [0, 0]        5        NaN   04 6, 2013
# 312310      312310  B009GU8B3S  [40, 46]        5        NaN  12 19, 2012
# 370839      370839  B00AJ099GC    [0, 0]        4        NaN  01 20, 2013
# 407344      407344  B00B1LH0OQ    [3, 3]        5        NaN  02 21, 2013
# 407624      407624  B00B1QG4WK    [1, 1]        5        NaN  01 18, 2013
# ...

# %%
# Remove null reviews from dataset

kindle_clean_1 = kindle_data.drop(review_na.index)
kindle_clean_1
# Out:
#         Unnamed: 0        asin helpful  overall  \
# 0                0  B000F83SZQ  [0, 0]        5
# 1                1  B000F83SZQ  [2, 2]        4
# 2                2  B000F83SZQ  [2, 2]        4
# 3                3  B000F83SZQ  [1, 1]        5
# 4                4  B000F83SZQ  [0, 1]        4
# ...            ...         ...     ...      ...
# 982614      982614  B00M13FNSS  [2, 2]        5
# 982615      982615  B00M13FNSS  [0, 0]        5
# 982616      982616  B00M13FNSS  [1, 1]        5
# 982617      982617  B00M13FNSS  [0, 0]        5
# 982618      982618  B00M13FNSS  [2, 2]        5
#
#                                                reviewText   reviewTime  \
# 0       I enjoy vintage books and movies so I enjoyed ...   05 5, 2014
# 1       This book is a reissue of an old one; the auth...   01 6, 2014
# 2       This was a fairly interesting read.  It had ol...   04 4, 2014
# 3       I'd never read any of the Amy Brewster mysteri...  02 19, 2014
# ...

# %%
# Search for null values in ratings

kindle_clean_1.loc[kindle_clean_1["overall"].isna(), :]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, asin, helpful, overall, reviewText, reviewTime, reviewerID, reviewerName, summary, unixReviewTime]
# Index: []

# %%
# Search for outlier/unusual values in ratings

kindle_clean_1.loc[kindle_clean_1["overall"] > 5]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, asin, helpful, overall, reviewText, reviewTime, reviewerID, reviewerName, summary, unixReviewTime]
# Index: []

# %%
# Check for missing dates

kindle_clean_1.loc[kindle_clean_1["unixReviewTime"].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, asin, helpful, overall, reviewText, reviewTime, reviewerID, reviewerName, summary, unixReviewTime]
# Index: []

# %%
# kindle_clean_1.to_csv("./kindle_data_clean.csv", index=False, header=True)

# %%
kindle_clean = kindle_clean_1
