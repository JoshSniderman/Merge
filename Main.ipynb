# %%
import pandas as pd

# %%
data_dummy = pd.read_csv("./Resources/SRS042628.genels.txt", sep="	")
data_dummy
# Out:
#                                                       GID        Score
# 0                Neisseria_meningitidis_FAM18_0|639827039  3160.450000
# 1                                    sp|Q1CS04|PYRE_HELPH    17.077600
# 2              Metallosphaera_sedula_DSM_5348_2|640506312    13.622000
# 3                                     sp|Q6SKG1|ACSM3_RAT    20.315000
# 4            Pelobacter_carbinolicus_DSM_2380_6|637750831   216.484000
# ...                                                   ...          ...
# 419093  Mycobacterium_avium_subsp._avium_ATCC_25291_68...     0.017383
# 419094               Mycobacterium_avium_104_79|639736316     0.017383
# 419095      Sebaldella_termitidis_ATCC_33386_10|645151862     0.102638
# 419096      Sebaldella_termitidis_ATCC_33386_44|646429430     0.102638
# 419097                                         modo153053     3.643660
#
# [419098 rows x 2 columns]

# %%
adult_data = pd.read_csv("./Resources/Autism-Adult-Data.csv")
adult_data
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ... Gender       Ethnicity Jundice Family  \
# ...
